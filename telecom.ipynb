# %% [markdown]
# # European Telecom Dataset Analysis using Python

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv(r"C:\Users\User\Desktop\study material\projects\datasets\Telecom industry analysis with python\telecom.csv")

# %%
data.head(5)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %%
data.shape
# Out:
# (3333, 21)

# %%
data.dtypes
# Out:
# state                      object
# account length              int64
# area code                   int64
# phone number               object
# international plan         object
# voice mail plan            object
# number vmail messages       int64
# total day minutes         float64
# total day calls             int64
# total day charge          float64
# total eve minutes         float64
# total eve calls             int64
# total eve charge          float64
# total night minutes       float64
# total night calls           int64
# total night charge        float64
# total intl minutes        float64
# total intl calls            int64
# total intl charge         float64
# customer service calls      int64
# churn                        bool
# dtype: object

# %%
data.nunique
# Out:
# <bound method DataFrame.nunique of      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
data.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %% [markdown]
# # Data Cleaning and Removing Duplicates

# %%
data.isna().sum()
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [state, account length, area code, phone number, international plan, voice mail plan, number vmail messages, total day minutes, total day calls, total day charge, total eve minutes, total eve calls, total eve charge, total night minutes, total night calls, total night charge, total intl minutes, total intl calls, total intl charge, customer service calls, churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
data.drop_duplicates()
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %% [markdown]
# # Analyzing the churn variable

# %%
data.head(2)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
data['churn'].unique()
# Out:
# array([False,  True])

# %%
data['churn'].value_counts()
# Out:
# churn
# False    2850
# True      483
# Name: count, dtype: int64

# %%
plt.pie(data['churn'].value_counts(),labels=[" Not Churned"," Churned"], colors=["orange","Lime"], startangle = 50, shadow=True, radius=2, explode=(0,0.2),
       autopct="%1.2f%%", pctdistance=0.75)

circle = plt.Circle((0,0),1,color="white")
c = plt.gcf()
c.gca().add_artist(circle)

plt.show()

# %% [markdown]
# ## Outcome = almost 15% customer are churned

# %% [markdown]
# # Analyzing the State Variable

# %%
data.head(2)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
data.state.unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
data["state"].value_counts()
# Out:
# state
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# OH     78
# OR     78
# WY     77
# VA     77
# CT     74
# MI     73
# ID     73
# VT     73
# TX     72
# UT     72
# IN     71
# MD     70
# KS     70
# NC     68
# NJ     68
# MT     68
# CO     66
# NV     66
# WA     66
# RI     65
# MA     65
# MS     65
# AZ     64
# FL     63
# MO     63
# NM     62
# ME     62
# ND     62
# NE     61
# OK     61
# DE     61
# SC     60
# SD     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# HI     53
# TN     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20,9))
sns.countplot(data["state"]);
plt.xticks(fontsize=13)
plt.ylabel("states",size=20)
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(20,7))
sns.countplot(x=data["state"], hue=data["churn"])
plt.show()

# %%
a= data.groupby("state")["churn"].mean()*100
a.sort_values()
# Out:
# state
# HI     5.660377
# AK     5.769231
# AZ     6.250000
# VA     6.493506
# IA     6.818182
# LA     7.843137
# NE     8.196721
# IL     8.620690
# WI     8.974359
# RI     9.230769
# DC     9.259259
# TN     9.433962
# WV     9.433962
# NM     9.677419
# ND     9.677419
# AL    10.000000
# VT    10.958904
# MO    11.111111
# WY    11.688312
# ID    12.328767
# IN    12.676056
# FL    12.698413
# OH    12.820513
# SD    13.333333
# KY    13.559322
# CO    13.636364
# UT    13.888889
# OR    14.102564
# OK    14.754098
# DE    14.754098
# GA    14.814815
# NH    16.071429
# NC    16.176471
# CT    16.216216
# MA    16.923077
# PA    17.777778
# MN    17.857143
# NY    18.072289
# KS    18.571429
# AR    20.000000
# MT    20.588235
# ME    20.967742
# WA    21.212121
# NV    21.212121
# MS    21.538462
# MI    21.917808
# SC    23.333333
# MD    24.285714
# TX    25.000000
# NJ    26.470588
# CA    26.470588
# Name: churn, dtype: float64

# %%
X = data["state"].unique()
Y = data.groupby("state")["churn"].mean()

sns.set(style="darkgrid")
plt.rcParams["figure.figsize"] = (20, 7)
plt.rcParams["lines.linestyle"] = "-"
plt.plot(X, Y, color="black", marker="*", markersize=10)

plt.xlabel("State")
plt.ylabel("Churn Rate")
plt.title("State-wise Churn Rate")
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %%
a= data.groupby("state")["churn"].mean().sort_values(ascending=False).head(5)*100
print(a)
# Out:
# state
# NJ    26.470588
# CA    26.470588
# TX    25.000000
# MD    24.285714
# SC    23.333333
# Name: churn, dtype: float64

# %%
c = pd.crosstab(data['state'], data['churn'], margins=True)
c['percentage_churns'] = (c[True] / c['All']) * 100

print(c.head())
print(type(c))
# Out:
# churn  False  True  All  percentage_churns
# state
# AK        49     3   52           5.769231
# AL        72     8   80          10.000000
# AR        44    11   55          20.000000
# AZ        60     4   64           6.250000
# CA        25     9   34          26.470588
# <class 'pandas.core.frame.DataFrame'>

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, AK to All
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   False              52 non-null     int64
#  1   True               52 non-null     int64
#  2   All                52 non-null     int64
#  3   percentage_churns  52 non-null     float64
# dtypes: float64(1), int64(3)
# memory usage: 2.0+ KB

# %%
sorted_c = c.sort_values(by='percentage_churns', ascending=False)
top_rows = sorted_c.head()

print(top_rows)
# Out:
# churn  False  True  All  percentage_churns
# state
# CA        25     9   34          26.470588
# NJ        50    18   68          26.470588
# TX        54    18   72          25.000000
# MD        53    17   70          24.285714
# SC        46    14   60          23.333333

# %% [markdown]
# ## this show the top 5 states with churn rate

# %% [markdown]
# # Analyzing the area code column

# %%
data.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
data["area code"].unique()
# Out:
# array([415, 408, 510], dtype=int64)

# %%
data["area code"].value_counts()
# Out:
# area code
# 415    1655
# 510     840
# 408     838
# Name: count, dtype: int64

# %%
data.groupby("area code")["churn"].mean()*100
# Out:
# area code
# 408    14.558473
# 415    14.259819
# 510    14.880952
# Name: churn, dtype: float64

# %% [markdown]
# d = pd.crosstab(data['area code'], data['churn'], margins=True)
# d['percentage_churns'] = (d[True] / d['All']) * 100
# print(d)

# %%
plt.figure(figsize=(10,7) )
sns.countplot(x= "area code", hue="churn", data=data);

# %% [markdown]
# # ANALYZING THE ACCOUNT LENGTH COLUMN

# %%
data.head(2)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
data["account length"].nunique()
# Out:
# 212

# %%
churn_data= data[data["churn"]==True]
non_churned_data= data[data["churn"]==False]

# %%
churn_data.head(2)
# Out:
#    state  account length  area code phone number international plan  \
# 10    IN              65        415     329-6603                 no
# 15    NY             161        415     351-7269                 no
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 10              no                      0              129.1              137
# 15              no                      0              332.9               67
#
#     total day charge  ...  total eve calls  total eve charge  \
# 10             21.95  ...               83             19.42
# 15             56.59  ...               97             27.01
#
#     total night minutes  total night calls  total night charge  \
# 10                208.8                111                9.40
# 15                160.6                128                7.23
#
#     total intl minutes  total intl calls  total intl charge  \
# 10                12.7                 6               3.43
# ...

# %%
non_churned_data.head(2)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 483 entries, 10 to 3323
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   483 non-null    object
#  1   account length          483 non-null    int64
#  2   area code               483 non-null    int64
#  3   phone number            483 non-null    object
#  4   international plan      483 non-null    object
#  5   voice mail plan         483 non-null    object
#  6   number vmail messages   483 non-null    int64
#  7   total day minutes       483 non-null    float64
#  8   total day calls         483 non-null    int64
#  9   total day charge        483 non-null    float64
#  10  total eve minutes       483 non-null    float64
#  11  total eve calls         483 non-null    int64
#  12  total eve charge        483 non-null    float64
#  13  total night minutes     483 non-null    float64
# ...

# %%
non_churned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2850 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   2850 non-null   object
#  1   account length          2850 non-null   int64
#  2   area code               2850 non-null   int64
#  3   phone number            2850 non-null   object
#  4   international plan      2850 non-null   object
#  5   voice mail plan         2850 non-null   object
#  6   number vmail messages   2850 non-null   int64
#  7   total day minutes       2850 non-null   float64
#  8   total day calls         2850 non-null   int64
#  9   total day charge        2850 non-null   float64
#  10  total eve minutes       2850 non-null   float64
#  11  total eve calls         2850 non-null   int64
#  12  total eve charge        2850 non-null   float64
#  13  total night minutes     2850 non-null   float64
# ...

# %%
# distribution plot

plt.figure(figsize=(10,7))
sns.histplot(data["account length"], color="orange")
plt.show()

# %%
sns.distplot(data["account length"], color="orange", label="all")
sns.distplot(churn_data["account length"],hist=False, color="grey",label="churned")
sns.distplot(non_churned_data["account length"],hist=False, color="red",label="not churned")
plt.rcParams["figure.figsize"]=(20,7);
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10008\3407414860.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["account length"], color="orange", label="all")
# C:\Users\User\AppData\Local\Temp\ipykernel_10008\3407414860.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# # Analyzing the Internation Plan column

# %%
data.head(2)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
data["international plan"].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data["international plan"].value_counts()
# Out:
# international plan
# no     3010
# yes     323
# Name: count, dtype: int64

# %%
yes_int_plans = data[(data["international plan"] == "yes") & (data["churn"] == True)]
print(yes_int_plans)
# Out:
#      state  account length  area code phone number international plan  \
# 41      MD             135        408     383-6029                yes
# 115     ME              36        510     363-1069                yes
# 144     VT             117        408     390-2390                yes
# 198     ME             131        510     353-7292                yes
# 214     FL              70        510     366-6345                yes
# ...    ...             ...        ...          ...                ...
# 3246    NC              77        408     334-6129                yes
# 3255    RI             138        510     411-6823                yes
# 3291    MI             119        510     335-7324                yes
# 3304    IL              71        510     330-7137                yes
# 3320    GA             122        510     411-5677                yes
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
no_int_plans = data[(data["international plan"] == "no") & (data["churn"] == True)]
print(no_int_plans)
# Out:
#      state  account length  area code phone number international plan  \
# 10      IN              65        415     329-6603                 no
# 15      NY             161        415     351-7269                 no
# 21      CO              77        408     393-7984                 no
# 33      AZ              12        408     360-1596                 no
# 48      ID             119        415     398-1294                 no
# ...    ...             ...        ...          ...                ...
# 3280    AR              76        408     345-3614                 no
# 3287    KS             170        415     404-5840                 no
# 3301    CA              84        415     417-1488                 no
# 3322    MD              62        408     409-1856                 no
# 3323    IN             117        415     362-5899                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
e = pd.crosstab(data['international plan'], data['churn'], margins=True)
e['percentage_churns'] = (e[True] / e['All']) * 100
print(e)
# Out:
# churn               False  True   All  percentage_churns
# international plan
# no                   2664   346  3010          11.495017
# yes                   186   137   323          42.414861
# All                  2850   483  3333          14.491449

# %%
e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, no to All
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   False              3 non-null      int64
#  1   True               3 non-null      int64
#  2   All                3 non-null      int64
#  3   percentage_churns  3 non-null      float64
# dtypes: float64(1), int64(3)
# memory usage: 120.0+ bytes

# %%
i=e.value_counts()
i
# Out:
# False  True  All   percentage_churns
# 186    137   323   42.414861            1
# 2664   346   3010  11.495017            1
# 2850   483   3333  14.491449            1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Assuming 'i' is your data array
i = [60, 40]

# Make sure the length of 'i' matches the length of 'labels'
labels = ["No", "Yes"]

# Other pie chart parameters
colors = ["yellow", "cyan"]
explode = (0, 0.2)
autopct = "%1.2f%%"
pctdistance = 0.75

# Plot the pie chart
plt.pie(i, labels=labels, colors=colors, startangle=50, shadow=True, radius=2, explode=explode, autopct=autopct, pctdistance=pctdistance)

# Add a white circle in the middle to make it look like a donut chart
circle = plt.Circle((0, 0), 1, color="white")
c = plt.gcf()
c.gca().add_artist(circle)

# Show the plot
plt.show()

# %% [markdown]
# ## Output-- many people dont have the internation plans

# %% [markdown]
# # Analyzing the number vmail column

# %%
data.head(2)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
data["number vmail messages"].unique()
# Out:
# array([25, 26,  0, 24, 37, 27, 33, 39, 30, 41, 28, 34, 46, 29, 35, 21, 32,
#        42, 36, 22, 23, 43, 31, 38, 40, 48, 18, 17, 45, 16, 20, 14, 19, 51,
#        15, 11, 12, 47,  8, 44, 49,  4, 10, 13, 50,  9], dtype=int64)

# %%
data["number vmail messages"].value_counts().head(10)
# Out:
# number vmail messages
# 0     2411
# 31      60
# 29      53
# 28      51
# 33      46
# 27      44
# 30      44
# 24      42
# 26      41
# 32      41
# Name: count, dtype: int64

# %%
data["number vmail messages"].describe()
# Out:
# count    3333.000000
# mean        8.099010
# std        13.688365
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        20.000000
# max        51.000000
# Name: number vmail messages, dtype: float64

# %%
sns.histplot(data["number vmail messages"]);

# %%
sns.boxplot(data=data, x="churn", y="number vmail messages", color="Red", meanline=True, showmeans=True)
plt.figure(figsize=(20,7))
plt.show()

# %% [markdown]
# # Analyzing the service calls column

# %%
data.head(2)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
data["customer service calls"].unique()
# Out:
# array([1, 0, 2, 3, 4, 5, 7, 9, 6, 8], dtype=int64)

# %%
data["customer service calls"].value_counts()
# Out:
# customer service calls
# 1    1181
# 2     759
# 0     697
# 3     429
# 4     166
# 5      66
# 6      22
# 7       9
# 9       2
# 8       2
# Name: count, dtype: int64

# %%
churn_data = data[data["churn"]]
churn_data
# Out:
#      state  account length  area code phone number international plan  \
# 10      IN              65        415     329-6603                 no
# 15      NY             161        415     351-7269                 no
# 21      CO              77        408     393-7984                 no
# 33      AZ              12        408     360-1596                 no
# 41      MD             135        408     383-6029                yes
# ...    ...             ...        ...          ...                ...
# 3301    CA              84        415     417-1488                 no
# 3304    IL              71        510     330-7137                yes
# 3320    GA             122        510     411-5677                yes
# 3322    MD              62        408     409-1856                 no
# 3323    IN             117        415     362-5899                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
churn_data["customer service calls"].value_counts()
# Out:
# customer service calls
# 1    122
# 0     92
# 2     87
# 4     76
# 3     44
# 5     40
# 6     14
# 7      5
# 9      2
# 8      1
# Name: count, dtype: int64

# %%
cscall = pd.crosstab(data['customer service calls'], data['churn'], margins=True)
cscall['percentage_churns'] = (cscall[True] / cscall['All']) * 100

cscall
# Out:
# churn                   False  True   All  percentage_churns
# customer service calls
# 0                         605    92   697          13.199426
# 1                        1059   122  1181          10.330229
# 2                         672    87   759          11.462451
# 3                         385    44   429          10.256410
# 4                          90    76   166          45.783133
# 5                          26    40    66          60.606061
# 6                           8    14    22          63.636364
# 7                           4     5     9          55.555556
# 8                           1     1     2          50.000000
# 9                           0     2     2         100.000000
# All                      2850   483  3333          14.491449

# %%
sns.countplot(x="customer service calls", hue="churn", color="violet", data=data)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5864\177804815.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:violet'` for the same effect.
#
#   sns.countplot(x="customer service calls", hue="churn", color="violet", data=data)

# %% [markdown]
# # Analyzing per minute charge

# %%
data.head(2)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
dc_pm=data["total day charge"].mean()/data["total day minutes"].mean()
ec_pm=data["total eve charge"].mean()/data["total eve minutes"].mean()
dc_pm=data["total night charge"].mean()/data["total night minutes"].mean()
dc_intl=data["total intl charge"].mean()/data["total intl minutes"].mean()

# %%
print(dc_pm)
print(ec_pm)
print(dc_pm)
print(dc_intl)
# Out:
# 0.04500041448440008
# 0.08500104871485778
# 0.04500041448440008
# 0.2700500279887107

# %%
sns.barplot(x=["day", "evening", "night", "int"], y=[dc_pm, ec_pm, dc_pm, dc_intl])

plt.show()

# %% [markdown]
# ## intl call rate per minute is high as compared to others

# %% [markdown]
# # END
